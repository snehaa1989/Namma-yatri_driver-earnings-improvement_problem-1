# %%
# %pip install pulp
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install sklearn
from pulp import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn
# Out:
# Requirement already satisfied: pulp in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (1.23.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (3.6.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\sneha\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sklearn in c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages (0.0.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#a handful of sites
sites = ['Basavanagudi','Bannerghatta Road','Indira Nagar','Electronic City','Jayanagar','Kengeri','Malleshwaram','Hosur Road','Rajajinagar','Lalbagh Road','Frazer Town','Sadashivanagar','Marathalli','Mathikere','HSR Layout','Ashok nagar','Bellandur','Hebbal','Bilekahalli','Vidyaranyapura','Ulsoor','Konanakunte','Jayamahal','Shanti nagar']
latlng = ['latitude', 'longitude']
position = pd.read_csv('./data/position.csv', index_col="City")
flighttime = pd.read_csv('./data/auto_travel_time.csv', index_col="City")
distance = pd.read_csv('./data/distance.csv', index_col="City")
position.head(5)
# print(len(sites))
# Out:
#                    latitude  longitude
# City
# Basavanagudi        41.3888     2.1590
# Bannerghatta Road   44.8040    20.4651
# Indira Nagar        52.5244    13.4105
# Electronic City     50.8505     4.3488
# Jayanagar           44.4323    26.1063

# %%
#make some positions (so we can plot this)
positions = dict( ( city, (position.loc[city, 'longitude'], position.loc[city, 'latitude']) ) for city in sites)

# %%
for s in positions:
    p = positions[s]
    plt.plot(p[0],p[1],'o')
    plt.text(p[0]+.01,p[1],s,horizontalalignment='left',verticalalignment='center')
    
plt.gca().axis('off');

# %%
# get distanc between cities
distances = dict( ((s1,s2), distance.loc[s1, s2] ) for s1 in positions for s2 in positions if s1!=s2)

# %% [markdown]
# ## The model
#
#
# For **K** vehicles or auto drivers:
#
# ### Variables:
#
# $x_{ij}=
# \begin{cases}
# 1: \text{the path goes from place i to j}\\
# 0: \text{otherwise}
# \end{cases}$
#
# ### order dummy variables:
#
# $u_i - u_j + C*x_{ij} \leq C - d_j, C = N/K$
# $\begin{cases}
# u_i: \text{order that site i is visited}\\
# d_j: \text{the cost to visit place j}, 0 \leq u_i \leq C - d_j, \forall i \in V \setminus \{0\}
# \end{cases}$
#
# ### Goal:
#
# $min\sum_{i=0}^{n}\sum_{j\neq{i}, j=0}^{n}{c_{ij}}{x_{ij}}$
# $\begin{cases}
# c_{ij}: \text{distance from place i to place j}\\
# x_{ij}: \text{whether there's a path between i and j}
# \end{cases}$
#
# ### Constraints:
#
# $\sum_{i\in{V}}{x_{ij} = 1}, \forall j \in V \setminus \{0\}$
#
# $\sum_{j\in{V}}{x_{ij} = 1}, \forall i \in V \setminus \{0\}$
#
# $\sum_{i\in{V}}{x_{i0} = K}$
#
# $\sum_{j\in{V}}{x_{0j} = K}$

# %%
K = 4 #the number of sales people

# %%
#create the problme
prob=LpProblem("vehicle", LpMinimize)

# %%
#indicator variable if site i is connected to site j in the tour
x = LpVariable.dicts('x',distances, 0,1,LpBinary)
#dummy vars to eliminate subtours
u = LpVariable.dicts('u', sites, 0, len(sites)-1, LpInteger)

# %%
#the objective
cost = lpSum([x[(i,j)]*distances[(i,j)] for (i,j) in distances])
prob+=cost

# %%
#constraints
for k in sites:
    cap = 1 if k != 'Indira Nagar' else K
    #inbound connection
    prob+= lpSum([ x[(i,k)] for i in sites if (i,k) in x]) ==cap
    #outbound connection
    prob+=lpSum([ x[(k,i)] for i in sites if (k,i) in x]) ==cap
    
#subtour elimination
N=len(sites)/K
for i in sites:
    for j in sites:
        if i != j and (i != 'Indira Nagar' and j!= 'Indira Nagar') and (i,j) in x:
            prob += u[i] - u[j] <= (N)*(1-x[(i,j)]) - 1

# %% [markdown]
# Solve it!

# %%
# %time prob.solve()
# prob.solve(GLPK_CMD(options=['--simplex']))
print(LpStatus[prob.status])

# %%
non_zero_edges = [ e for e in x if value(x[e]) != 0 ]

def get_next_site(parent):
    '''helper function to get the next edge'''
    edges = [e for e in non_zero_edges if e[0]==parent]
    for e in edges:
        non_zero_edges.remove(e)
    return edges

# %%
tours = get_next_site('Indira Nagar')
tours = [ [e] for e in tours ]

for t in tours:
    while t[-1][1] !='Indira Nagar':
        t.append(get_next_site(t[-1][1])[-1])

# %% [markdown]
# The optimal route:

# %%
for t in tours:
    print(' -> '.join([ a for a,b in t]+['Indira Nagar']))
# Out:
# Berlin -> Budapest -> Bucharest -> Istanbul -> Sofia -> Belgrade -> Vienna -> Berlin
# Berlin -> Hamburg -> Dublin -> London -> Paris -> Brussels -> Berlin
# Berlin -> Prague -> Rome -> Barcelona -> Madrid -> Milan -> Munich -> Berlin
# Berlin -> Warsaw -> Kiev -> Moscow -> Saint Petersburg -> Stockholm -> Copenhagen -> Berlin

# %% [markdown]
# Calculate total time:

# %%
totalTime = 0;
for t in tours:
    time = 0
    for i in range(0, len(t)):
        time += flighttime.loc[t[i][0], t[i][1]]
#         print(flighttime.loc[t[i][0], t[i][1]])
#     print(time)
    if time > totalTime:
        totalTime = time
print(totalTime)
# Out:
# 1988

# %%
#draw the tours
colors = [np.random.rand(3) for i in range(len(tours))]
for t,c in zip(tours,colors):
    for a,b in t:
        p1,p2 = positions[a], positions[b]
        plt.plot([p1[0],p2[0]],[p1[1],p2[1]], color=c)

#draw the map again
for s in positions:
    p = positions[s]
    plt.plot(p[0],p[1],'o')
    plt.text(p[0]+.01,p[1],s,horizontalalignment='left',verticalalignment='center')
    
plt.title('%d '%K + 'people' if K > 1 else 'person')
plt.xlabel('latitude')
plt.ylabel('longitude')
# plt.gca().axis('off')
plt.show()

# %%
print('Longest time spent:', totalTime, '(min)')
print('Total distance:', value(prob.objective), '(km)')
# Out:
# Longest time spent: 1988 (min)
# Total distance: 15425.02 (km)
